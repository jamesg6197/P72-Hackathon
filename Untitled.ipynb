# %%
import requests

# %%
requests.get("https://gbfs.lyft.com/gbfs/2.3/bkn/en/station_information.json").json()
# Out:
# {'data': {'stations': [{'name': 'Vesey St & Church St',
#     'lat': 40.71221958009051,
#     'capacity': 48,
#     'short_name': '5216.06',
#     'lon': -74.01047229766846,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#      'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'station_id': '06439006-11b6-44f0-8545-c9d39035f32a',
#     'region_id': '71'},
#    {'name': '6 Ave & Walker St',
#     'lat': 40.7197920901383,
#     'capacity': 39,
#     'short_name': '5430.10',
#     'lon': -74.0052238852195,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#      'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#     'station_id': '19d17911-1e4a-41fa-b62b-719aa0a6182e',
#     'region_id': '71'},
#    {'name': 'W 67 St & Broadway',
#     'lat': 40.77492513,
#     'capacity': 31,
#     'short_name': '7116.04',
#     'lon': -73.98266566,
#     'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
# ...

# %%
requests.get("https://gbfs.lyft.com/gbfs/2.3/bkn/en/station_status.json").json()["data"]["stations"][10]
# Out:
# {'last_reported': 1714187696,
#  'num_scooters_available': 0,
#  'num_scooters_unavailable': 0,
#  'num_docks_available': 10,
#  'is_renting': 1,
#  'is_installed': 1,
#  'num_ebikes_available': 5,
#  'is_returning': 1,
#  'num_bikes_available': 16,
#  'station_id': '6e5a8cab-cf1a-4584-8133-01835b56ad71',
#  'num_docks_disabled': 0,
#  'num_bikes_disabled': 1,
#  'vehicle_types_available': [{'vehicle_type_id': '1', 'count': 11},
#   {'vehicle_type_id': '2', 'count': 5}]}

# %%
requests.get("https://gbfs.lyft.com/gbfs/2.3/bkn/en/station_information.json").json()["data"]["stations"][10]
# Out:
# {'lat': 40.87471,
#  'capacity': 21,
#  'name': 'Marble Hill Ave & W 225 St',
#  'rental_uris': {'ios': 'https://bkn.lft.to/lastmile_qr_scan',
#   'android': 'https://bkn.lft.to/lastmile_qr_scan'},
#  'short_name': '8745.01',
#  'lon': -73.91099,
#  'station_id': '1869753654337059182'}
